# %%
import pandas as pd
import finnhub as fin
import json
import time
import numpy as np

# %%
#insert API key
fin_client = fin.Client(api_key="insert_your_API_key_here")

# %%
#read in the previously created csv
df = pd.read_csv('ESG_scores_with_ticker_exchange.csv')
df
# Out:
#                              name  Environment  Emissions  Resource Use  \
# 0                  Amazon.com Inc           89         98            82
# 1                    Chevron Corp           81         86            75
# 2                  Home Depot Inc           86         89            84
# 3             Elevance Health Inc           85         97            99
# 4                       Kroger Co           85         83            93
# ...                           ...          ...        ...           ...
# 2810                   Zoetis Inc           64         64            83
# 2811                   Zumiez Inc            5         12             0
# 2812                    Zuora Inc           27         57            45
# 2813  Zynerba Pharmaceuticals Inc            0          0             0
# 2814                    Zynex Inc            0          0             0
#
#       Innovation  Social  Human Rights  Product Responsibiliy  Workforce  \
# 0             80      91            95                     91         88
# 1             81      86            93                     77         77
# 2             86      72            44                     79         62
# 3              0      89            90                     92         93
# 4             78      87            60                     99         87
# ...          ...     ...           ...                    ...        ...
# 2810           0      78            68                     64         94
# 2811           0      29            44                     25         17
# 2812           0      60            73                     35         75
# 2813           0      35             0                     30         29
# 2814           0      34             0                     73         13
#
#       Community  Governance  Management  Shareholders  CSR Strategy  \
# 0            92          81          84            86          60.0
# 1            94          97          98            96          94.0
# 2            90          65          58            86          72.0
# 3            81          84          91            51          98.0
# 4            95          65          65            60          72.0
# ...         ...         ...         ...           ...           ...
# 2810         87          56          55            60          55.0
# 2811         33          30          39            19           0.0
# 2812         67          48          59            17          40.0
# 2813         50          19          17            39           0.0
# 2814         35          27          17            77           0.0
#
#       ESG Score ticker exchange
# 0            87   AMZN   NASDAQ
# 1            87    CVX     NYSE
# 2            72     HD     NYSE
# 3            86    ELV     NYSE
# 4            80     KR     NYSE
# ...         ...    ...      ...
# 2810         68    ZTS     NYSE
# 2811         25   ZUMZ   NASDAQ
# 2812         50    ZUO     NYSE
# 2813         20   ZYNE   NASDAQ
# 2814         25   ZYXI   NASDAQ
#
# [2815 rows x 17 columns]

# %%
#create a list out of the company tickers
ticker_list = df['ticker'].tolist()
ticker_list
# Out:
# ['AMZN',
#  'CVX',
#  'HD',
#  'ELV',
#  'KR',
#  'META',
#  'LOW',
#  'PG',
#  'ACI',
#  'DIS',
#  'GS',
#  'RTX',
#  'BA',
#  'TSLA',
#  'ALL',
#  'TJX',
#  'PGR',
#  'SNEX',
#  'PAGP',
#  'TMO',
#  'TRV',
#  'QCOM',
#  'DHI',
#  'CRM',
#  'KHC',
#  'USB',
#  'BX',
#  'HIG',
#  'AFL',
#  'MAN',
#  'PCG',
#  'CARR',
#  'BKR',
#  'SHW',
#  'PNC',
#  'KSS',
#  'JLL',
#  'SCHW',
#  'MA',
#  'DINO',
#  'TXN',
#  'VTRS',
#  'HRB',
#  'GT',
#  'TRGP',
#  'AEP',
#  'GPS',
#  'EL ',
#  'LH',
#  'OTIS',
#  'GLW',
#  'AMP',
#  'ORLY',
#  'RKT',
#  'GWW',
#  'ANDE',
#  'CYH',
#  'MOS',
#  'DKS',
#  'NEM',
#  'WBD',
#  'JBHT',
#  'VST',
#  'AES',
#  'CZR',
#  'EQH',
#  'DGX',
#  'TAP',
#  'IPG',
#  'WRB',
#  'ODP',
#  'HSY',
#  'DAN',
#  'JXN',
#  'CG',
#  'OVV',
#  'COMM',
#  'OC',
#  'OPEN',
#  'SJM',
#  'HOUS',
#  'GXO',
#  'BCC',
#  'BBWI',
#  'TROW',
#  'VRTX',
#  'ARNC',
#  'SAIC',
#  'CLX',
#  'TA ',
#  'KLAC',
#  'INGR',
#  'ASO',
#  'DDS',
#  'ARKO',
#  'FYBR',
#  'A',
#  'AA',
#  'AAL',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAT',
#  'AXON',
#  'AB',
#  'ABB',
#  'ABBV',
#  'ABC',
#  'ABCB',
#  'ABEO',
#  'ABEV',
#  'ABG',
#  'ABMD',
#  'ABR',
#  'ABT',
#  'ABUS',
#  'AC',
#  'ACA',
#  'ACAD',
#  'ACB',
#  'ACCO',
#  'ACER',
#  'ACGL',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACOR',
#  'ACRE',
#  'ACRS',
#  'ACRX',
#  'ACTG',
#  'ACU',
#  'ADAP',
#  'ADBE',
#  'ADC',
#  'ADES',
#  'ADI',
#  'ADM',
#  'ADMA',
#  'ADMP',
#  'ADNT',
#  'ADP',
#  'ADPT',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADUS',
#  'ADVM',
#  'AE',
#  'AEE',
#  'AEIS',
#  'AEL',
#  'AEO',
#  'AER',
#  'AERI',
#  'ARCC',
#  'AFG',
#  'AFMD',
#  'AG',
#  'AGCO',
#  'AGE',
#  'AGEN',
#  'AGFS',
#  'AGI',
#  'AGIO',
#  'AGM',
#  'AGNC',
#  'AGO',
#  'AGR',
#  'AGRO',
#  'AGRX',
#  'AGS',
#  'AGTC',
#  'AGX',
#  'AGYS',
#  'AHH',
#  'AHT',
#  'AI',
#  'AIG',
#  'AIMC',
#  'AIN',
#  'AINC',
#  'AIR',
#  'AIRG',
#  'AIT',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AJX',
#  'AKAM',
#  'AKBA',
#  'AKO.A',
#  'AKR',
#  'AKRO',
#  'AKTS',
#  'AL',
#  'ALB',
#  'ALBO',
#  'ALCO',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALG',
#  'ALGN',
#  'ALGT',
#  'ALK',
#  'ALKS',
#  'ALLE',
#  'ALLK',
#  'ALLO',
#  'ALLT',
#  'ALLY',
#  'ALNY',
#  'ALOT',
#  'ALRN',
#  'ALRS',
#  'ALSN',
#  'ALT',
#  'ALTR',
#  'ALV',
#  'ALX',
#  'ALYA',
#  'AM',
#  'AMAL',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMC',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AMED',
#  'AMEH',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMK',
#  'AMKR',
#  'AMN',
#  'AMNB',
#  'AMOT',
#  'AMOV',
#  'AMPE',
#  'AMPH',
#  'AMRC',
#  'AMRK',
#  'AMRS',
#  'AMRX',
#  'AMSC',
#  'AMSF',
#  'AMSWA',
#  'AMT',
#  'AMTB',
#  'AMTX',
#  'AMWD',
#  'AN',
#  'ANAB',
#  'ANET',
#  'ANF',
#  'ANGI',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANSS',
#  'AON',
#  'AP',
#  'APA',
#  'APAM',
#  'APD',
#  'APEI',
#  'APEN',
#  'APH',
#  'APLE',
#  'APLS',
#  'APLT',
#  'APO',
#  'APOG',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APRN',
#  'APT',
#  'APTO',
#  'APTV',
#  'APTX',
#  'APYX',
#  'AQB',
#  'AQN',
#  'AQST',
#  'AQUA',
#  'AR',
#  'ARAV',
#  'ARC',
#  'ARCB',
#  'ARCO',
#  'ARCT',
#  'ARDX',
#  'ARE',
#  'ARES',
#  'ARGD',
#  'ARGX',
#  'ARL',
#  'ARLO',
#  'ARLP',
#  'ARMK',
#  'AROC',
#  'AROW',
#  'ARR',
#  'ARTNA',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'ASB',
#  'ASC',
#  'ASIX',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASPN',
#  'ASPS',
#  'ASPU',
#  'ASTE',
#  'ASUR',
#  'ASX',
#  'ASYS',
#  'ATEC',
#  'ATEN',
#  'ATEX',
#  'ATGE',
#  'ATHM',
#  'ATHX',
#  'ATKR',
#  'ATLC',
#  'ATLO',
#  'ATNI',
#  'ATNM',
#  'ATNX',
#  'ATO',
#  'ATR',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATSG',
#  'ATTO',
#  'ATUS',
#  'ATVI',
#  'ATXI',
#  'AUB',
#  'AUBN',
#  'AUPH',
#  'AUY',
#  'AVA',
#  'AVAL',
#  'AVAV',
#  'AVB',
#  'AVCO',
#  'AVD',
#  'AVEO',
#  'AVGO',
#  'AVID',
#  'AVLR',
#  'AVNS',
#  'AVNW',
#  'AVRO',
#  'AVT',
#  'AVTR',
#  'AVXL',
#  'AVY',
#  'AVYA',
#  'AWI',
#  'AWR',
#  'AX',
#  'AXAS',
#  'AXDX',
#  'AXGN',
#  'AXL',
#  'AXLA',
#  'AXNX',
#  'AXP',
#  'AXSM',
#  'AXTA',
#  'AXTI',
#  'AYTU',
#  'AYX',
#  'AZN',
#  'AZO',
#  'AZPN',
#  'AZUL',
#  'AZZ',
#  'B',
#  'BAC',
#  'BAH',
#  'BAM',
#  'BANC',
#  'BAND',
#  'BANF',
#  'BANR',
#  'BAP',
#  'BATRA',
#  'BAX',
#  'BBBY',
#  'BBD',
#  'BBDC',
#  'BBGI',
#  'BBIO',
#  'BBSI',
#  'BBU',
#  'BBW',
#  'BBY',
#  'BC',
#  'BCE',
#  'BCEL',
#  'BCH',
#  'BCLI',
#  'BCML',
#  'BCOR',
#  'BCOV',
#  'BCPC',
#  'BCRX',
#  'BCS',
#  'BCSF',
#  'BDC',
#  'BDN',
#  'BDX',
#  'BE',
#  'BECN',
#  'BELFA',
#  'BEN',
#  'BEP',
#  'BERY',
#  'BEST',
#  'BFAM',
#  'BFC',
#  'BFIN',
#  'BFS',
#  'BFST',
#  'BGCP',
#  'BGFV',
#  'BGNE',
#  'BGS',
#  'BGSF',
#  'BH',
#  'BHC',
#  'BHE',
#  'BHF',
#  'BHLB',
#  'BHR',
#  'BIDU',
#  'BIG',
#  'BIIB',
#  'BILI',
#  'OPCH',
#  'BIP',
#  'BJ',
#  'BJRI',
#  'BK',
#  'BKD',
#  'BKE',
#  'BKH',
#  'BKI',
#  'BKNG',
#  'BKU',
#  'BL',
#  'BLBD',
#  'BLCM',
#  'BLD',
#  'BLDP',
#  'BLDR',
#  'BLFS',
#  'BLK',
#  'BLKB',
#  'BALL',
#  'BLNK',
#  'BLPH',
#  'BLUE',
#  'C',
#  'BMI',
#  'BMRC',
#  'BMRN',
#  'BMY',
#  'BNED',
#  'BNFT',
#  'BNGO',
#  'BOH',
#  'BOKF',
#  'BOC',
#  'BOOM',
#  'BOOT',
#  'BOX',
#  'BP',
#  'BPMC',
#  'BPOP',
#  'BR',
#  'BRC',
#  'BRFS',
#  'BRID',
#  'BRK.A',
#  'BRKL',
#  'BRKR',
#  'BRO',
#  'BRT',
#  'BRX',
#  'BSIG',
#  'BSBR',
#  'BSGM',
#  'BSRR',
#  'BSVN',
#  'BSX',
#  'BTAI',
#  'BTG',
#  'BTI',
#  'BTU',
#  'BURL',
#  'BUSE',
#  'BV',
#  'BWA',
#  'BWB',
#  'BWFG',
#  'BWXT',
#  'BXC',
#  'BXP',
#  'BY',
#  'BYD',
#  'BYND',
#  'BYSI',
#  'BZH',
#  'BZUN',
#  'CAAP',
#  'CAAS',
#  'CABO',
#  'CAC',
#  'CACC',
#  'CACI',
#  'CAE',
#  'CAG',
#  'CAH',
#  'CAJ',
#  'CAL',
#  'CALA',
#  'CALM',
#  'CALX',
#  'CAMP',
#  'CANG',
#  'CAR',
#  'CARA',
#  'CARG',
#  'CASA',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CAT',
#  'CATC',
#  'CATY',
#  'CBAN',
#  'CBAY',
#  'CBD',
#  'CBFV',
#  'CBL',
#  'CBNK',
#  'CBOE',
#  'CBRE',
#  'CBRL',
#  'CBSH',
#  'CBT',
#  'CBU',
#  'CBZ',
#  'CCF',
#  'CCI',
#  'CCJ',
#  'CCK',
#  'CCL',
#  'CCLP',
#  'CCNE',
#  'CCO',
#  'CCOI',
#  'CCRN',
#  'CCS',
#  'CCU',
#  'CCXI',
#  'CCZ',
#  'CDAY',
#  'CDE',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDTX',
#  'CDW',
#  'CDXC',
#  'CDXS',
#  'CDZI',
#  'CE',
#  'CEA',
#  'CECE',
#  'CEIX',
#  'CELC',
#  'CELH',
#  'CEMI',
#  'CENT',
#  'CENX',
#  'CEPU',
#  'CEQP',
#  'CERS',
#  'CEVA',
#  'CF',
#  'CFB',
#  'CFFI',
#  'CFFN',
#  'CFG',
#  'CFMS',
#  'CFR',
#  'CFRX',
#  'CGC',
#  'CGNX',
#  'CHCO',
#  'CHD',
#  'CHE',
#  'CHGG',
#  'CHH',
#  'CHK',
#  'CHKP',
#  'CHMG',
#  'CHMI',
#  'CHRA',
#  'CHRS',
#  'CHRW',
#  'CHT',
#  'CHTR',
#  'CHWY',
#  'CI',
#  'CIA',
#  'CIB',
#  'CIDM',
#  'CIEN',
#  'CIM',
#  'CINF',
#  'CIO',
#  'CIR',
#  'CIZN',
#  'CKPT',
#  'CL',
#  'CLAR',
#  'CLB',
#  'CLBK',
#  'CLDX',
#  'CLF',
#  'CLFD',
#  'CLH',
#  'CLLS',
#  'CLNE',
#  'CLPR',
#  'CLS',
#  'CLSD',
#  'CLVS',
#  'CLW',
#  'CLXT',
#  'CM',
#  'CMBM',
#  'CMC',
#  'CMCM',
#  'CMCO',
#  'CMCT',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMLS',
#  'CMP',
#  'CMRE',
#  'CMRX',
#  'CMS',
#  'CMT',
#  'CMTL',
#  'CNA',
#  'CNC',
#  'CNCE',
#  'CNHI',
#  'CNI',
#  'CNK',
#  'CNMD',
#  'CNNE',
#  'CNO',
#  'CNOB',
#  'CNP',
#  'CNS',
#  'CNSL',
#  'CNTY',
#  'CNXN',
#  'CO',
#  'CODA',
#  'CODI',
#  'CODX',
#  'COE',
#  'COF',
#  'COHR',
#  'COHU',
#  'COKE',
#  'COLB',
#  'COLD',
#  'COLL',
#  'COLM',
#  'COP',
#  'CORR',
#  'COST',
#  'COTY',
#  'COWN',
#  'CPA',
#  'CPB',
#  'CPE',
#  'CPG',
#  'CPK',
#  'CPRT',
#  'CPRX',
#  'CPS',
#  'CPSI',
#  'CPSS',
#  'CPT',
#  'CQP',
#  'CR',
#  'CRBP',
#  'CRC',
#  'CRD.A',
#  'CRESY',
#  'CRH',
#  'CRIS',
#  'CRK',
#  'CRL',
#  'CRMD',
#  'CRNT',
#  'CRNX',
#  'CRON',
#  'CROX',
#  'CRS',
#  'CRSP',
#  'CRTO',
#  'CRUS',
#  'CRVL',
#  'CRVS',
#  'CRWD',
#  'CSBR',
#  'CSCO',
#  'CSGP',
#  'CSGS',
#  'CSII',
#  'CSIQ',
#  'CSSE',
#  'CSTE',
#  'CSTL',
#  'CSTM',
#  'CSTR',
#  'CSV',
#  'CSWI',
#  'CSX',
#  'CTAS',
#  'CTBI',
#  'CTIC',
#  'CTLT',
#  'CTMX',
#  'CTRA',
#  'CTRE',
#  'CTRN',
#  'CTS',
#  'CTSH',
#  'CTSO',
#  'CTVA',
#  'CTXR',
#  'CUBE',
#  'CUBI',
#  'CUE',
#  'CULP',
#  'CURO',
#  'CUTR',
#  'CVBF',
#  'CVCO',
#  'CVCY',
#  'CVE',
#  'CVEO',
#  'CVET',
#  'CVGI',
#  'CVGW',
#  'CVI',
#  'CVLT',
#  'CVLY',
#  'CVM',
#  'CVNA',
#  'CVS',
#  'CW',
#  'CWBR',
#  'CWCO',
#  'CWEN',
#  'CWH',
#  'CWK',
#  'CWST',
#  'CX',
#  'CXW',
#  'CYBR',
#  'CYRN',
#  'CYRX',
#  'CZNC',
#  'D',
#  'DAC',
#  'DAL',
#  'DAR',
#  'DAVA',
#  'DB',
#  'DBI',
#  'DBVT',
#  'DBX',
#  'DCOM',
#  'DCPH',
#  'DD',
#  'DDD',
#  'DE',
#  'DEA',
#  'DECK',
#  'DEI',
#  'DELL',
#  'DEO',
#  'DFIN',
#  'DFS',
#  'DG',
#  'DGICA',
#  'DGII',
#  'DHIL',
#  'DHR',
#  'DHT',
#  'DHX',
#  'DIN',
#  'DISH',
#  'DK',
#  'DLA',
#  'DLHC',
#  'DLR',
#  'DLTH',
#  'DLTR',
#  'DLX',
#  'DMRC',
#  'DMTK',
#  'DNLI',
#  'DNOW',
#  'DO',
#  'DOC',
#  'DOCU',
#  'DOMO',
#  'DOOO',
#  'DOOR',
#  'DORM',
#  'DOV',
#  'DOW',
#  'DQ',
#  'DRH',
#  'DRI',
#  'DRQ',
#  'DRRX',
#  'DS',
#  'DSKE',
#  'DSX',
#  'DT',
#  'DTE',
#  'DTIL',
#  'DUK',
#  'DVA',
#  'DVAX',
#  'DVN',
#  'DWSN',
#  'DX',
#  'DXC',
#  'DXCM',
#  'DXLG',
#  'DXPE',
#  'DY',
#  'DYAI',
#  'E',
#  'EA',
#  'EAF',
#  'EARN',
#  'EAT',
#  'EB',
#  'EBAY',
#  'EBF',
#  'EBIX',
#  'EBMT',
#  'EBS',
#  'EBTC',
#  'EC',
#  'ECL',
#  'ECOM          ',
#  'ECPG',
#  'ED',
#  'EDIT',
#  'EDU',
#  'EEFT',
#  'EFC',
#  'EFSC',
#  'EFX',
#  'EGAN',
#  'EGBN',
#  'EGHT',
#  'EGLE',
#  'EGO',
#  'EGP',
#  'EGRX',
#  'EHC',
#  'EHTH',
#  'EIG',
#  'EIGR',
#  'EIX',
#  'ELMD',
#  'ELOX',
#  'ELS',
#  'ELVT',
#  'EME',
#  'EMKR',
#  'EMN',
#  'EMR',
#  'ENB',
#  'ENIC',
#  'ENLC',
#  'ENOB',
#  'ENPH',
#  'ENR',
#  'ENS',
#  'ENTA',
#  'ENTG',
#  'ENV',
#  'ENVA',
#  'ENZ',
#  'EOG',
#  'EOLS',
#  'EPAM',
#  'EPD',
#  'EPR',
#  'EPRT',
#  'EQ',
#  'EQBK',
#  'EQC',
#  'EQIX',
#  'EQNR',
#  'EQR',
#  'EQT',
#  'ERF',
#  'ERIE',
#  'ERII',
#  'ERJ',
#  'ERYP',
#  'ES',
#  'ESE',
#  'ESI',
#  'ESLT',
#  'ESNT',
#  'ESPR',
#  'ESQ',
#  'ESRT',
#  'ESS',
#  'ESSA',
#  'ESTA',
#  'ESTC',
#  'ESTE',
#  'ET',
#  'ETD',
#  'ETON',
#  'ETR',
#  'ETRN',
#  'ETSY',
#  'EURN',
#  'EVA',
#  'EVBG',
#  'EVBN',
#  'EVC',
#  'EVER',
#  'EVFM',
#  'EVH',
#  'EVI',
#  'EVLO',
#  'EVOP',
#  'EVR',
#  'EVRG',
#  'EVRI',
#  'EVTC',
#  'EW',
#  'EWBC',
#  'EXAS',
#  'EXC',
#  'EXEL',
#  'EXK',
#  'EXLS',
#  'EXP',
#  'EXPD',
#  'EXPE',
#  'EXPI',
#  'EXPO',
#  'EXPR',
#  'EXR',
#  'EXTN',
#  'EXTR',
#  ...]

# %%
#create new dataframe to hold the percentage of women
df_women = pd.DataFrame(index=['Share of Women'])
df_women
# Out:
# Empty DataFrame
# Columns: []
# Index: [Share of Women]

# %%
#loop through the list of tickers and get the gender of each company's executives; 
#then calculate the share of female executives and add it to the df

counter = 0
for i in ticker_list:
    counter += 1
    executives = fin_client.company_executive(i)
    execs_sex = [item['sex'] for item in executives['executive']]
    female = execs_sex.count('female')
    male = execs_sex.count('male')
    try:
        share_of_fems = round((female / (male + female))*100,2)
    except ZeroDivisionError:
        share_of_fems = 0
    
    df_women[i] = share_of_fems
    
    if counter % 100 == 0:
        time.sleep(30)
    
df_women
# Out:
#                 AMZN   CVX     HD    ELV    KR  META    LOW    PG    ACI  \
# Share of Women  40.0  37.5  26.09  33.33  44.0  37.5  31.58  50.0  28.57
#
#                  DIS  ...    ZEN  ZEUS     ZM     ZS   ZTO    ZTS   ZUMZ  \
# Share of Women  50.0  ...  31.58  25.0  27.78  16.67  7.14  40.91  21.43
#
#                   ZUO   ZYNE   ZYXI
# Share of Women  28.57  16.67  16.67
#
# [1 rows x 2815 columns]

# %%
#create a new Dataframe to hold the company revenue
df_revs = pd.DataFrame(index=['Avg revenue'])
df_revs
# Out:
# Empty DataFrame
# Columns: []
# Index: [Avg revenue]

# %%
#loop through the tickers and get the annual revenue for each company;
#then calculate the average revenue over the last four years (2021 through 2018)

counter = 0
revs = []

for i in ticker_list: 
    counter += 1 
    finance = fin_client.financials(i, 'ic', 'annual')
    try:
        revs = [item['revenue'] for item in finance['financials']]
    except (KeyError, TypeError):
        continue
        
    four_revs = revs[:4]
    avg = round(sum(four_revs)/4)
    df_revs[i] = avg
    
    revs = []
    
    if counter % 100 == 0:
        time.sleep(30)
    
df_revs
# Out:
#                AMZN     CVX      HD     ELV      KR   META    LOW     PG  \
# Avg revenue  342324  137250  125424  114224  128458  82607  82326  73735
#
#                ACI    DIS  ...  ZEN  ZEUS    ZM   ZS    ZTO   ZTS  ZUMZ  ZUO  \
# Avg revenue  66142  65462  ...  946  1710  1926  625  23834  6634  1047  291
#
#              ZYNE  ZYXI
# Avg revenue     0    72
#
# [1 rows x 2531 columns]

# %%
#create a new dataframe to hold the employee number for each company
df_employees = pd.DataFrame(index=['Employees'])
df_employees
# Out:
# Empty DataFrame
# Columns: []
# Index: [Employees]

# %%
#loop through the tickers and get the employee number for each company

counter = 0
for i in ticker_list:  
    counter += 1 
    profile = fin_client.company_profile(symbol=i)
    try:
        emps = profile['employeeTotal']
    except (KeyError, TypeError):
        continue
        
    df_employees[i] = emps
    
    if counter % 100 == 0:
        time.sleep(30)
    
df_employees
# Out:
#               AMZN    CVX      HD    ELV      KR   META     LOW      PG  \
# Employees  1608000  42595  490600  98200  420000  83553  200000  106000
#
#               ACI     DIS  ...   ZEN  ZEUS    ZM    ZS    ZTO    ZTS  ZUMZ  \
# Employees  290000  190000  ...  6540  1644  8044  4975  23865  12100  2500
#
#             ZUO  ZYNE  ZYXI
# Employees  1393    28   774
#
# [1 rows x 2815 columns]

# %%
#create a new dataframe to hold the industry group for each company
df_group = pd.DataFrame(index=['Group'])
df_group
# Out:
# Empty DataFrame
# Columns: []
# Index: [Group]

# %%
#loop through the tickers and get the industry group for each company

counter = 0
for i in ticker_list: 
    counter += 1 
    profile = fin_client.company_profile(symbol=i)
    try:
        group = profile['ggroup']
    except (KeyError, TypeError):
        continue
    
    df_group[i] = group
    
    if counter % 100 == 0:
        time.sleep(30)
    
df_group
# Out:
#             AMZN     CVX         HD                               ELV  \
# Group  Retailing  Energy  Retailing  Health Care Equipment & Services
#
#                              KR                   META        LOW  \
# Group  Food & Staples Retailing  Media & Entertainment  Retailing
#
#                                   PG                       ACI  \
# Group  Household & Personal Products  Food & Staples Retailing
#
#                          DIS  ...                  ZEN       ZEUS  \
# Group  Media & Entertainment  ...  Software & Services  Materials
#
#                         ZM                   ZS             ZTO  \
# Group  Software & Services  Software & Services  Transportation
#
#                                                   ZTS       ZUMZ  \
# Group  Pharmaceuticals, Biotechnology & Life Sciences  Retailing
#
#                        ZUO                                            ZYNE  \
# Group  Software & Services  Pharmaceuticals, Biotechnology & Life Sciences
#
#                                    ZYXI
# Group  Health Care Equipment & Services
#
# [1 rows x 2815 columns]

# %%
#create a new dataframe to hold the industry sector for each company
df_sector = pd.DataFrame(index=['Sector'])
df_sector
# Out:
# Empty DataFrame
# Columns: []
# Index: [Sector]

# %%
#loop through the tickers and get the industry sector for each company

counter = 0
for i in ticker_list:
    counter += 1 
    profile = fin_client.company_profile(symbol=i)
    try:
        sector = profile['gsector']
    except (KeyError, TypeError):
        continue
        print(f"No industry sector for {i} available")
    
    df_sector[i] = sector
    
    if counter % 100 == 0:
        time.sleep(30)
    
df_sector
# Out:
#                           AMZN     CVX                      HD          ELV  \
# Sector  Consumer Discretionary  Energy  Consumer Discretionary  Health Care
#
#                       KR                    META                     LOW  \
# Sector  Consumer Staples  Communication Services  Consumer Discretionary
#
#                       PG               ACI                     DIS  ...  \
# Sector  Consumer Staples  Consumer Staples  Communication Services  ...
#
#                            ZEN       ZEUS                      ZM  \
# Sector  Information Technology  Materials  Information Technology
#
#                             ZS          ZTO          ZTS  \
# Sector  Information Technology  Industrials  Health Care
#
#                           ZUMZ                     ZUO         ZYNE  \
# Sector  Consumer Discretionary  Information Technology  Health Care
#
#                ZYXI
# Sector  Health Care
#
# [1 rows x 2815 columns]

# %%
# join all the dataframes together for each company/ticker
df_list = [df_women, df_revs, df_employees, df_group, df_sector]
df_finn = pd.concat(df_list, axis=0) 
df_finn
# Out:
#                                   AMZN     CVX                      HD  \
# Share of Women                    40.0    37.5                   26.09
# Avg revenue                     342324  137250                  125424
# Employees                      1608000   42595                  490600
# Group                        Retailing  Energy               Retailing
# Sector          Consumer Discretionary  Energy  Consumer Discretionary
#
#                                              ELV                        KR  \
# Share of Women                             33.33                      44.0
# Avg revenue                               114224                    128458
# Employees                                  98200                    420000
# Group           Health Care Equipment & Services  Food & Staples Retailing
# Sector                               Health Care          Consumer Staples
#
#                                   META                     LOW  \
# Share of Women                    37.5                   31.58
# Avg revenue                      82607                   82326
# Employees                        83553                  200000
# Group            Media & Entertainment               Retailing
# Sector          Communication Services  Consumer Discretionary
#
#                                            PG                       ACI  \
# Share of Women                           50.0                     28.57
# Avg revenue                             73735                     66142
# Employees                              106000                    290000
# Group           Household & Personal Products  Food & Staples Retailing
# Sector                       Consumer Staples          Consumer Staples
#
#                                    DIS  ...                     ZEN  \
# Share of Women                    50.0  ...                   31.58
# Avg revenue                      65462  ...                     946
# Employees                       190000  ...                    6540
# Group            Media & Entertainment  ...     Software & Services
# Sector          Communication Services  ...  Information Technology
#
#                      ZEUS                      ZM                      ZS  \
# Share of Women       25.0                   27.78                   16.67
# Avg revenue          1710                    1926                     625
# Employees            1644                    8044                    4975
# Group           Materials     Software & Services     Software & Services
# Sector          Materials  Information Technology  Information Technology
#
#                            ZTO  \
# Share of Women            7.14
# Avg revenue              23834
# Employees                23865
# Group           Transportation
# Sector             Industrials
#
#                                                            ZTS  \
# Share of Women                                           40.91
# Avg revenue                                               6634
# Employees                                                12100
# Group           Pharmaceuticals, Biotechnology & Life Sciences
# Sector                                             Health Care
#
#                                   ZUMZ                     ZUO  \
# Share of Women                   21.43                   28.57
# Avg revenue                       1047                     291
# Employees                         2500                    1393
# Group                        Retailing     Software & Services
# Sector          Consumer Discretionary  Information Technology
#
#                                                           ZYNE  \
# Share of Women                                           16.67
# Avg revenue                                                  0
# Employees                                                   28
# Group           Pharmaceuticals, Biotechnology & Life Sciences
# Sector                                             Health Care
#
#                                             ZYXI
# Share of Women                             16.67
# Avg revenue                                   72
# Employees                                    774
# Group           Health Care Equipment & Services
# Sector                               Health Care
#
# [5 rows x 2815 columns]

# %%
df_finnhub = df_finn.transpose()
df_finnhub.index.rename('ticker', inplace=True)
df_finnhub
# Out:
#        Share of Women Avg revenue Employees  \
# ticker
# AMZN             40.0      342324   1608000
# CVX              37.5      137250     42595
# HD              26.09      125424    490600
# ELV             33.33      114224     98200
# KR               44.0      128458    420000
# ...               ...         ...       ...
# ZTS             40.91        6634     12100
# ZUMZ            21.43        1047      2500
# ZUO             28.57         291      1393
# ZYNE            16.67           0        28
# ZYXI            16.67          72       774
#
#                                                  Group                  Sector
# ticker
# AMZN                                         Retailing  Consumer Discretionary
# CVX                                             Energy                  Energy
# HD                                           Retailing  Consumer Discretionary
# ELV                   Health Care Equipment & Services             Health Care
# KR                            Food & Staples Retailing        Consumer Staples
# ...                                                ...                     ...
# ZTS     Pharmaceuticals, Biotechnology & Life Sciences             Health Care
# ZUMZ                                         Retailing  Consumer Discretionary
# ZUO                                Software & Services  Information Technology
# ZYNE    Pharmaceuticals, Biotechnology & Life Sciences             Health Care
# ZYXI                  Health Care Equipment & Services             Health Care
#
# [2815 rows x 5 columns]

# %%
# read in the other spreadsheet with the ESG data and ticker symbols and merge the two dataframes
final_complete_df = pd.merge(df, 
                     df_finnhub, 
                     on ='ticker', 
                     how ='left')
final_complete_df
# Out:
#                              name  Environment  Emissions  Resource Use  \
# 0                  Amazon.com Inc           89         98            82
# 1                    Chevron Corp           81         86            75
# 2                  Home Depot Inc           86         89            84
# 3             Elevance Health Inc           85         97            99
# 4                       Kroger Co           85         83            93
# ...                           ...          ...        ...           ...
# 2810                   Zoetis Inc           64         64            83
# 2811                   Zumiez Inc            5         12             0
# 2812                    Zuora Inc           27         57            45
# 2813  Zynerba Pharmaceuticals Inc            0          0             0
# 2814                    Zynex Inc            0          0             0
#
#       Innovation  Social  Human Rights  Product Responsibiliy  Workforce  \
# 0             80      91            95                     91         88
# 1             81      86            93                     77         77
# 2             86      72            44                     79         62
# 3              0      89            90                     92         93
# 4             78      87            60                     99         87
# ...          ...     ...           ...                    ...        ...
# 2810           0      78            68                     64         94
# 2811           0      29            44                     25         17
# 2812           0      60            73                     35         75
# 2813           0      35             0                     30         29
# 2814           0      34             0                     73         13
#
#       Community  ...  Shareholders  CSR Strategy  ESG Score  ticker  exchange  \
# 0            92  ...            86          60.0         87    AMZN    NASDAQ
# 1            94  ...            96          94.0         87     CVX      NYSE
# 2            90  ...            86          72.0         72      HD      NYSE
# 3            81  ...            51          98.0         86     ELV      NYSE
# 4            95  ...            60          72.0         80      KR      NYSE
# ...         ...  ...           ...           ...        ...     ...       ...
# 2810         87  ...            60          55.0         68     ZTS      NYSE
# 2811         33  ...            19           0.0         25    ZUMZ    NASDAQ
# 2812         67  ...            17          40.0         50     ZUO      NYSE
# 2813         50  ...            39           0.0         20    ZYNE    NASDAQ
# 2814         35  ...            77           0.0         25    ZYXI    NASDAQ
#
#      Share of Women Avg revenue Employees  \
# 0              40.0      342324   1608000
# 1              37.5      137250     42595
# 2             26.09      125424    490600
# 3             33.33      114224     98200
# 4              44.0      128458    420000
# ...             ...         ...       ...
# 2810          40.91        6634     12100
# 2811          21.43        1047      2500
# 2812          28.57         291      1393
# 2813          16.67           0        28
# 2814          16.67          72       774
#
#                                                Group                  Sector
# 0                                          Retailing  Consumer Discretionary
# 1                                             Energy                  Energy
# 2                                          Retailing  Consumer Discretionary
# 3                   Health Care Equipment & Services             Health Care
# 4                           Food & Staples Retailing        Consumer Staples
# ...                                              ...                     ...
# 2810  Pharmaceuticals, Biotechnology & Life Sciences             Health Care
# 2811                                       Retailing  Consumer Discretionary
# 2812                             Software & Services  Information Technology
# 2813  Pharmaceuticals, Biotechnology & Life Sciences             Health Care
# 2814                Health Care Equipment & Services             Health Care
#
# [2815 rows x 22 columns]

# %%
final_complete_df.to_csv("final_ESG_score_finnhub_data.csv", index=False)

# %%
# use matplotlib to get a sense of the distribution of female executives and directors

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)

plt.hist(final_complete_df['Share of Women'], color='#bc5090')
plt.title("Distribution of % of female executives among U.S. listed companies")
plt.ylabel("No. of companies")
plt.xlabel("% of female executives and board members")
plt.savefig("women_share_distribution.png", dpi=100)
plt.show()
